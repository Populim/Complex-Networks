# %% [markdown]
# # Exercício 1

# %% [markdown]
# E-road network:<br>
# Hamsterster friendships<br>
# C. elegans neural network<br>
# US airport network<br>
# <br>

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import warnings
import time
import pandas as pd
from numba import cuda
warnings.filterwarnings("ignore")

# %%
G = nx.read_edgelist("petsterhamsters.txt")

# %%
plt.figure(figsize=(6,4))
nx.draw_networkx(G,node_size=10,with_labels=False)

# %%
@jit
def functionabc(G):
    Gc = max(nx.connected_component_subgraphs(G), key=len)
    AvgShor = nx.average_shortest_path_length(Gc)

# %%
# DO NOT REPORT THIS... COMPILATION TIME IS INCLUDED IN THE EXECUTION TIME!
start = time.time()
functionabc(G)
end = time.time()
print("Elapsed (with compilation) = %s" % (end - start))

# NOW THE FUNCTION IS COMPILED, RE-TIME IT EXECUTING FROM CACHE
start = time.time()
functionabc(G)
end = time.time()
print("Elapsed (after compilation) = %s" % (end - start))
# Out:
# Elapsed (with compilation) = 13.777237892150879
# Elapsed (after compilation) = 14.341532945632935

# %%
G = nx.read_edgelist("euroroad.txt")

# %%
plt.figure(figsize=(6,4))
nx.draw_networkx(G,node_size=10,with_labels=False)

# %%
Gc = max(nx.connected_component_subgraphs(G), key=len)

# %%
start = time.time()
AvgShor = nx.average_shortest_path_length(Gc)
end = time.time()
print(end - start)
# Out:
# 2.303265333175659

# %%
print(len(Gc), len(G))
# Out:
# 1039 1174
